# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install changefinder
#!pip install fbprophet
# !pip install shap
# !pip install holoviews==1.18.1
# !pip install hvplot==0.9.0
# !pip install param==2.0.1
# !pip install prophet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %env HV_DOC_HTML=true
import numpy as np
import pandas as pd
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from matplotlib import pyplot as plt
import seaborn as sns
import os
import changefinder
from scipy import stats
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.stattools import adfuller
from prophet import Prophet
from sklearn.metrics import mean_absolute_error
import shap
shap.initjs()
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
from tabulate import tabulate
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout
from keras.layers import Bidirectional
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
# Out:
# env: HV_DOC_HTML=true
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ...

# %%
#Adding dataset to pandas library
df = pd.read_csv("d:/Neel/Neel - Master's/UMBC/Sem 1/CMSC 671 - Principles of AI/Project/Code/dataset/HomeC.csv",low_memory=False)
print(f'HomeC.csv : {df.shape}')
df.head(3)
# Out:
# HomeC.csv : (503911, 32)
#          time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 0  1451624400  0.932833  0.003483            0.932833         0.000033
# 1  1451624401  0.934333  0.003467            0.934333         0.000000
# 2  1451624402  0.931817  0.003467            0.931817         0.000017
#
#    Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  Fridge [kW]  \
# 0        0.020700        0.061917          0.442633     0.124150
# 1        0.020717        0.063817          0.444067     0.124000
# 2        0.020700        0.062317          0.446067     0.123533
#
#    Wine cellar [kW]  ...  visibility  summary  apparentTemperature  pressure  \
# 0          0.006983  ...        10.0    Clear                29.26   1016.91
# 1          0.006983  ...        10.0    Clear                29.26   1016.91
# 2          0.006983  ...        10.0    Clear                29.26   1016.91
#
#    windSpeed  cloudCover  windBearing  precipIntensity  dewPoint  \
# ...

# %% [markdown]
# # **Pre-Processing**

# %%
df.columns
# Out:
# Index(['time', 'use [kW]', 'gen [kW]', 'House overall [kW]', 'Dishwasher [kW]',
#        'Furnace 1 [kW]', 'Furnace 2 [kW]', 'Home office [kW]', 'Fridge [kW]',
#        'Wine cellar [kW]', 'Garage door [kW]', 'Kitchen 12 [kW]',
#        'Kitchen 14 [kW]', 'Kitchen 38 [kW]', 'Barn [kW]', 'Well [kW]',
#        'Microwave [kW]', 'Living room [kW]', 'Solar [kW]', 'temperature',
#        'icon', 'humidity', 'visibility', 'summary', 'apparentTemperature',
#        'pressure', 'windSpeed', 'cloudCover', 'windBearing', 'precipIntensity',
#        'dewPoint', 'precipProbability'],
#       dtype='object')

# %%
#Removing kW from the column names
df.columns = [i.replace(' [kW]', '') for i in df.columns]

# %%
df.columns
# Out:
# Index(['time', 'use', 'gen', 'House overall', 'Dishwasher', 'Furnace 1',
#        'Furnace 2', 'Home office', 'Fridge', 'Wine cellar', 'Garage door',
#        'Kitchen 12', 'Kitchen 14', 'Kitchen 38', 'Barn', 'Well', 'Microwave',
#        'Living room', 'Solar', 'temperature', 'icon', 'humidity', 'visibility',
#        'summary', 'apparentTemperature', 'pressure', 'windSpeed', 'cloudCover',
#        'windBearing', 'precipIntensity', 'dewPoint', 'precipProbability'],
#       dtype='object')

# %%
#Summing all the values of Multiple Applicances to Single Applicances
# For example Furance has 2 Applicances and Kitchen has 3 Applicances
df['Furnace'] = df[['Furnace 1','Furnace 2']].sum(axis=1)
df['Kitchen'] = df[['Kitchen 12','Kitchen 14','Kitchen 38']].sum(axis=1)
df.drop(['Furnace 1','Furnace 2','Kitchen 12','Kitchen 14','Kitchen 38','icon','summary'], axis=1, inplace=True)

# %%
df[df.isnull().any(axis=1)]
df = df[0:-1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503910 entries, 0 to 503909
# Data columns (total 27 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   time                 503910 non-null  object
#  1   use                  503910 non-null  float64
#  2   gen                  503910 non-null  float64
#  3   House overall        503910 non-null  float64
#  4   Dishwasher           503910 non-null  float64
#  5   Home office          503910 non-null  float64
#  6   Fridge               503910 non-null  float64
#  7   Wine cellar          503910 non-null  float64
#  8   Garage door          503910 non-null  float64
#  9   Barn                 503910 non-null  float64
#  10  Well                 503910 non-null  float64
#  11  Microwave            503910 non-null  float64
#  12  Living room          503910 non-null  float64
#  13  Solar                503910 non-null  float64
# ...

# %%
print(df['cloudCover'].unique())
print('------------------------------------------------------------------------')
print(df[df['cloudCover']=='cloudCover'].shape)
# Out:
# ['cloudCover' '0.75' '0' '1' '0.31' '0.44' '0.13' '0.19' '0.25' '0.16'
#  '0.21' '0.15' '0.14' '0.27' '0.28' '0.17' '0.05' '0.1' '0.26' '0.29'
#  '0.11' '0.09' '0.12' '0.06' '0.02' '0.08' '0.04' '0.35' '0.22' '0.23'
#  '0.54' '0.39' '0.03' '0.07' '0.76' '0.62' '0.18' '0.79' '0.48' '0.24'
#  '0.57' '0.41' '0.78' '0.2' '0.77' '0.46' '0.55' '0.01' '0.51' '0.47'
#  '0.5' '0.4' '0.3' '0.43' '0.33' '0.6' '0.68' '0.66' '0.45' '0.34' '0.52'
#  '0.67' '0.49' '0.37' '0.36' '0.61' '0.38' '0.42' '0.53' '0.63' '0.32'
#  '0.56' '0.58' '0.72' '0.73' '0.71' '0.64' '0.59']
# ------------------------------------------------------------------------
# (58, 27)

# %%
df['cloudCover'].replace(['cloudCover'], method='bfill', inplace=True)
df['cloudCover'] = df['cloudCover'].astype('float')

# %%
pd.to_datetime(df['time'], unit='s').head(3)
# Out:
# The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
# 0   2016-01-01 05:00:48
# 1   2016-01-01 05:00:48
# 2   2016-01-01 05:00:48
# Name: time, dtype: datetime64[ns]

# %%
df['time'] = pd.DatetimeIndex(pd.date_range('2016-01-01 05:00', periods=len(df),  freq='min'))
df.head(3)
# Out:
#                  time       use       gen  House overall  Dishwasher  \
# 0 2016-01-01 05:00:00  0.932833  0.003483       0.932833    0.000033
# 1 2016-01-01 05:01:00  0.934333  0.003467       0.934333    0.000000
# 2 2016-01-01 05:02:00  0.931817  0.003467       0.931817    0.000017
#
#    Home office    Fridge  Wine cellar  Garage door      Barn  ...  \
# 0     0.442633  0.124150     0.006983     0.013083  0.031350  ...
# 1     0.444067  0.124000     0.006983     0.013117  0.031500  ...
# 2     0.446067  0.123533     0.006983     0.013083  0.031517  ...
#
#    apparentTemperature  pressure  windSpeed  cloudCover  windBearing  \
# 0                29.26   1016.91       9.18        0.75        282.0
# 1                29.26   1016.91       9.18        0.75        282.0
# 2                29.26   1016.91       9.18        0.75        282.0
#
#    precipIntensity  dewPoint  precipProbability   Furnace   Kitchen
# 0              0.0      24.4                0.0  0.082617  0.000567
# ...

# %%
#Formatting the year, month, day, weekday, weekofyear, hour, minute
df['year'] = df['time'].apply(lambda x : x.year)
df['month'] = df['time'].apply(lambda x : x.month)
df['day'] = df['time'].apply(lambda x : x.day)
df['weekday'] = df['time'].apply(lambda x : x.day_name())
df['weekofyear'] = df['time'].apply(lambda x : x.weekofyear)
df['hour'] = df['time'].apply(lambda x : x.hour)
df['minute'] = df['time'].apply(lambda x : x.minute)
df.head(3)
# Out:
#                  time       use       gen  House overall  Dishwasher  \
# 0 2016-01-01 05:00:00  0.932833  0.003483       0.932833    0.000033
# 1 2016-01-01 05:01:00  0.934333  0.003467       0.934333    0.000000
# 2 2016-01-01 05:02:00  0.931817  0.003467       0.931817    0.000017
#
#    Home office    Fridge  Wine cellar  Garage door      Barn  ...  \
# 0     0.442633  0.124150     0.006983     0.013083  0.031350  ...
# 1     0.444067  0.124000     0.006983     0.013117  0.031500  ...
# 2     0.446067  0.123533     0.006983     0.013083  0.031517  ...
#
#    precipProbability   Furnace   Kitchen  year  month  day  weekday  \
# 0                0.0  0.082617  0.000567  2016      1    1   Friday
# 1                0.0  0.084533  0.000567  2016      1    1   Friday
# 2                0.0  0.083017  0.000617  2016      1    1   Friday
#
#    weekofyear  hour  minute
# 0          53     5       0
# 1          53     5       1
# 2          53     5       2
#
# [3 rows x 34 columns]

# %%
def hours2timing(x):
    if x in [22,23,0,1,2,3]:
        timing = 'Night'
    elif x in range(4, 12):
        timing = 'Morning'
    elif x in range(12, 17):
        timing = 'Afternoon'
    elif x in range(17, 22):
        timing = 'Evening'
    else:
        timing = 'X'
    return timing

# %%
df['timing'] = df['hour'].apply(hours2timing)
df.head(3)
# Out:
#                  time       use       gen  House overall  Dishwasher  \
# 0 2016-01-01 05:00:00  0.932833  0.003483       0.932833    0.000033
# 1 2016-01-01 05:01:00  0.934333  0.003467       0.934333    0.000000
# 2 2016-01-01 05:02:00  0.931817  0.003467       0.931817    0.000017
#
#    Home office    Fridge  Wine cellar  Garage door      Barn  ...   Furnace  \
# 0     0.442633  0.124150     0.006983     0.013083  0.031350  ...  0.082617
# 1     0.444067  0.124000     0.006983     0.013117  0.031500  ...  0.084533
# 2     0.446067  0.123533     0.006983     0.013083  0.031517  ...  0.083017
#
#     Kitchen  year  month  day  weekday  weekofyear  hour  minute   timing
# 0  0.000567  2016      1    1   Friday          53     5       0  Morning
# 1  0.000567  2016      1    1   Friday          53     5       1  Morning
# 2  0.000617  2016      1    1   Friday          53     5       2  Morning
#
# [3 rows x 35 columns]

# %%
# House overall energy consumption - use and Generate Solar - gen_Sol 
df['use_HO'] = df['use']
df['gen_Sol'] = df['gen']
df.drop(['use','House overall','gen','Solar'], axis=1, inplace=True)
df.head(3)
# Out:
#                  time  Dishwasher  Home office    Fridge  Wine cellar  \
# 0 2016-01-01 05:00:00    0.000033     0.442633  0.124150     0.006983
# 1 2016-01-01 05:01:00    0.000000     0.444067  0.124000     0.006983
# 2 2016-01-01 05:02:00    0.000017     0.446067  0.123533     0.006983
#
#    Garage door      Barn      Well  Microwave  Living room  ...  year  month  \
# 0     0.013083  0.031350  0.001017   0.004067     0.001517  ...  2016      1
# 1     0.013117  0.031500  0.001017   0.004067     0.001650  ...  2016      1
# 2     0.013083  0.031517  0.001000   0.004067     0.001650  ...  2016      1
#
#    day  weekday  weekofyear  hour  minute   timing    use_HO   gen_Sol
# 0    1   Friday          53     5       0  Morning  0.932833  0.003483
# 1    1   Friday          53     5       1  Morning  0.934333  0.003467
# 2    1   Friday          53     5       2  Morning  0.931817  0.003467
#
# [3 rows x 33 columns]

# %%
consump = hv.Distribution(df['use_HO']).opts(title="Consumption Distribution of Total Energy", color="red")
generate = hv.Distribution(df['gen_Sol']).opts(title="Generation Distribution of Total Energy", color="blue")
(consump + generate).opts(opts.Distribution(xlabel="Energy Consumption", ylabel="Density", xformatter='%.1fkw', width=400, height=300,tools=['hover'],show_grid=True))
# Out:
# :Layout
#    .Distribution.I  :Distribution   [use_HO]   (Density)
#    .Distribution.II :Distribution   [gen_Sol]   (Density)

# %%
dish_w = hv.Distribution(df[df['Dishwasher']<1.5]['Dishwasher'],label="Dishwasher").opts(color="red")
home_o = hv.Distribution(df[df['Home office']<1.5]['Home office'],label="Home office").opts(color="blue")
re_fridge = hv.Distribution(df[df['Fridge']<1.5]['Fridge'],label="Fridge Distribution").opts(color="orange")
wine_c = hv.Distribution(df[df['Wine cellar']<1.5]['Wine cellar'],label="Wine cellar").opts(color="green")
garage_d = hv.Distribution(df[df['Garage door']<1.5]['Garage door'],label="Garage door").opts(color="purple")
barn = hv.Distribution(df[df['Barn']<1.5]['Barn'],label="Barn").opts(color="grey")
well = hv.Distribution(df[df['Well']<1.5]['Well'],label="Well").opts(color="pink")
micro_w = hv.Distribution(df[df['Microwave']<1.5]['Microwave'],label="Microwave").opts(color="yellow")
living_r = hv.Distribution(df[df['Living room']<1.5]['Living room'],label="Living room").opts(color="brown")
furance = hv.Distribution(df[df['Furnace']<1.5]['Furnace'],label="Furnace").opts(color="skyblue")
kitchen = hv.Distribution(df[df['Kitchen']<1.5]['Kitchen'],label="Kitchen").opts(color="lightgreen")

(dish_w * home_o * re_fridge * wine_c * garage_d * barn * well * micro_w * living_r * furance * kitchen).opts(opts.Distribution(xlabel="Energy Consumption", ylabel="Density", xformatter='%.1fkw',title='Energy Consumption of Appliances Distribution', \
                                                                               width=800, height=350,tools=['hover'],show_grid=True))
# Out:
# :Overlay
#    .Distribution.Dishwasher          :Distribution   [Dishwasher]   (Density)
#    .Distribution.Home_office         :Distribution   [Home office]   (Density)
#    .Distribution.Fridge_Distribution :Distribution   [Fridge]   (Density)
#    .Distribution.Wine_cellar         :Distribution   [Wine cellar]   (Density)
#    .Distribution.Garage_door         :Distribution   [Garage door]   (Density)
#    .Distribution.Barn                :Distribution   [Barn]   (Density)
#    .Distribution.Well                :Distribution   [Well]   (Density)
#    .Distribution.Microwave           :Distribution   [Microwave]   (Density)
#    .Distribution.Living_room         :Distribution   [Living room]   (Density)
#    .Distribution.Furnace             :Distribution   [Furnace]   (Density)
#    .Distribution.Kitchen             :Distribution   [Kitchen]   (Density)

# %%
tempera = hv.Distribution(df['temperature'],label="temperature").opts(color="red")
ap_Temp = hv.Distribution(df['apparentTemperature'],label="apparentTemperature").opts(color="orange")
temp_s = (tempera * ap_Temp).opts(opts.Distribution(title='Distribution Temperature')).opts(legend_position='top',legend_cols=2)
humdi = hv.Distribution(df['humidity']).opts(color="yellow", title='Distribution Humidity')
visib = hv.Distribution(df['visibility']).opts(color="blue", title='Distribution Visibility')
pressure = hv.Distribution(df['pressure']).opts(color="green", title='Distribution Pressure')
wind_s = hv.Distribution(df['windSpeed']).opts(color="purple", title='Distribution WindSpeed')
cloud_co = hv.Distribution(df['cloudCover']).opts(color="grey", title='Distribution CloudCover')
precip_int = hv.Distribution(df['precipIntensity']).opts(color="skyblue", title='Distribution PrecipIntensity')
dew_po = hv.Distribution(df['dewPoint']).opts(color="lightgreen", title='Distribution DewPoint')

(temp_s + humdi + visib + pressure + wind_s + cloud_co + precip_int + dew_po).opts(opts.Distribution(xlabel="Values", ylabel="Density", width=400, height=300,tools=['hover'],show_grid=True)).cols(4)
# Out:
# :Layout
#    .Overlay.I        :Overlay
#       .Distribution.Temperature         :Distribution   [temperature]   (Density)
#       .Distribution.ApparentTemperature :Distribution   [apparentTemperature]   (Density)
#    .Distribution.I   :Distribution   [humidity]   (Density)
#    .Distribution.II  :Distribution   [visibility]   (Density)
#    .Distribution.III :Distribution   [pressure]   (Density)
#    .Distribution.IV  :Distribution   [windSpeed]   (Density)
#    .Distribution.V   :Distribution   [cloudCover]   (Density)
#    .Distribution.VI  :Distribution   [precipIntensity]   (Density)
#    .Distribution.VII :Distribution   [dewPoint]   (Density)

# %%
#Grouping Fields by Month
def groupByMonth(col):
    return df[[col,'month']].groupby('month').agg({col:['mean']})[col]

# %%
#Grouping Fields by Weekday
def groupByWeekday(col):
    Weekdays = df.groupby('weekday').agg({col:['mean']})
    Weekdays.columns = [f"{i[0]}_{i[1]}" for i in Weekdays.columns]
    Weekdays['week_num'] = [['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'].index(i) for i in Weekdays.index]
    Weekdays.sort_values('week_num', inplace=True)
    Weekdays.drop('week_num', axis=1, inplace=True)
    return Weekdays

# %%
#Grouping Fields by Timing
def groupByTiming(col):
    timings = df.groupby('timing').agg({col:['mean']})
    timings.columns = [f"{i[0]}_{i[1]}" for i in timings.columns]
    timings['timing_num'] = [['Morning','Afternoon','Evening','Night'].index(i) for i in timings.index]
    timings.sort_values('timing_num', inplace=True)
    timings.drop('timing_num', axis=1, inplace=True)
    return timings

# %%
df = df.set_index(df['time'])
consump = hv.Curve(df['use_HO'].resample('D').mean()).opts(title="Consumption of Total Energy by Day Time-Series", color="red", ylabel="Energy Consumption")
generate = hv.Curve(df['gen_Sol'].resample('D').mean()).opts(title="Generation Total Energy by Day Time-Series", color="blue", ylabel="Energy Generation")
(consump + generate).opts(opts.Curve(xlabel="Day", yformatter='%.1fkw', width=400, height=300,tools=['hover'],show_grid=True,fontsize={'title':11}))
# Out:
# :Layout
#    .Curve.I  :Curve   [time]   (use_HO)
#    .Curve.II :Curve   [time]   (gen_Sol)

# %%
consump = hv.Curve(groupByMonth('use_HO')).opts(title="Total Energy Consumption Time-Series by Month", color="red", ylabel="Energy Consumption")
generate = hv.Curve(groupByMonth('gen_Sol')).opts(title="Total Energy Generation Time-Series by Month", color="blue", ylabel="Energy Generation")
(consump + generate).opts(opts.Curve(xlabel="Month", yformatter='%.1fkw', width=400, height=300,tools=['hover'],show_grid=True,fontsize={'title':10})).opts(shared_axes=False)
# Out:
# :Layout
#    .Curve.I  :Curve   [month]   (mean)
#    .Curve.II :Curve   [month]   (mean)

# %%
consump = hv.Curve(groupByTiming('use_HO')).opts(title="Total Energy Consumption Time-Series by Timing", color="red", ylabel="Energy Consumption")
generate = hv.Curve(groupByTiming('gen_Sol')).opts(title="Total Energy Generation Time-Series by Timing", color="blue", ylabel="Energy Generation")
(consump + generate).opts(opts.Curve(xlabel="Timing", yformatter='%.1fkw', width=400, height=300,tools=['hover'],show_grid=True,fontsize={'title':10})).opts(shared_axes=False)
# Out:
# :Layout
#    .Curve.I  :Curve   [timing]   (use_HO_mean)
#    .Curve.II :Curve   [timing]   (gen_Sol_mean)

# %%
dish_w = hv.Curve(df['Dishwasher'].resample('D').mean(),label="Dishwasher Time-Series by Day").opts(color="red")
home_o = hv.Curve(df['Home office'].resample('D').mean(),label="Home office Time-Series by Day").opts(color="blue")
re_fridge = hv.Curve(df['Fridge'].resample('D').mean(),label="Fridge Time-Series by Day").opts(color="orange")
wine_c = hv.Curve(df['Wine cellar'].resample('D').mean(),label="Wine cellar Time-Series by Day").opts(color="green")
garage_d = hv.Curve(df['Garage door'].resample('D').mean(),label="Garage door Time-Series by Day").opts(color="purple")
barn = hv.Curve(df['Barn'].resample('D').mean(),label="Barn Time-Series by Day").opts(color="grey")
well = hv.Curve(df['Well'].resample('D').mean(),label="Well Time-Series by Day").opts(color="pink")
micro_w = hv.Curve(df['Microwave'].resample('D').mean(),label="Microwave Time-Series by Day").opts(color="yellow")
living_r = hv.Curve(df['Living room'].resample('D').mean(),label="Living room Time-Series by Day").opts(color="brown")
furance = hv.Curve(df['Furnace'].resample('D').mean(),label="Furnace Time-Series by Day").opts(color="skyblue")
kitchen = hv.Curve(df['Kitchen'].resample('D').mean(),label="Kitchen Time-Series by Day").opts(color="lightgreen")

(dish_w + home_o + re_fridge + wine_c + garage_d + barn + well + micro_w + living_r + furance + kitchen).opts(opts.Curve(xlabel="Day", ylabel="Energy Consumption", yformatter='%.2fkw' , \
                                                                               width=400, height=300,tools=['hover'],show_grid=True)).cols(6)
# Out:
# :Layout
#    .Curve.Dishwasher_Time_hyphen_minus_Series_by_Day  :Curve   [time]   (Dishwasher)
#    .Curve.Home_office_Time_hyphen_minus_Series_by_Day :Curve   [time]   (Home office)
#    .Curve.Fridge_Time_hyphen_minus_Series_by_Day      :Curve   [time]   (Fridge)
#    .Curve.Wine_cellar_Time_hyphen_minus_Series_by_Day :Curve   [time]   (Wine cellar)
#    .Curve.Garage_door_Time_hyphen_minus_Series_by_Day :Curve   [time]   (Garage door)
#    .Curve.Barn_Time_hyphen_minus_Series_by_Day        :Curve   [time]   (Barn)
#    .Curve.Well_Time_hyphen_minus_Series_by_Day        :Curve   [time]   (Well)
#    .Curve.Microwave_Time_hyphen_minus_Series_by_Day   :Curve   [time]   (Microwave)
#    .Curve.Living_room_Time_hyphen_minus_Series_by_Day :Curve   [time]   (Living room)
#    .Curve.Furnace_Time_hyphen_minus_Series_by_Day     :Curve   [time]   (Furnace)
#    .Curve.Kitchen_Time_hyphen_minus_Series_by_Day     :Curve   [time]   (Kitchen)

# %%
dish_w = hv.Curve(groupByMonth('Dishwasher'),label="Time-Series of Dishwasher by Month").opts(color="red")
home_o = hv.Curve(groupByMonth('Home office'),label="Time-Series of Home office by Month").opts(color="blue")
re_fridge = hv.Curve(groupByMonth('Fridge'),label="Time-Series of Fridge by Month").opts(color="orange")
wine_c = hv.Curve(groupByMonth('Wine cellar'),label="Time-Series of Wine cellar by Month").opts(color="green")
garage_d = hv.Curve(groupByMonth('Garage door'),label="Time-Series of Garage door by Month").opts(color="purple")
barn = hv.Curve(groupByMonth('Barn'),label="Time-Series of Barn by Month").opts(color="grey")
well = hv.Curve(groupByMonth('Well'),label="Time-Series of Well by Month").opts(color="pink")
micro_w = hv.Curve(groupByMonth('Microwave'),label="Time-Series of Microwave by Month").opts(color="yellow")
living_r = hv.Curve(groupByMonth('Living room'),label="Time-Series of Living room by Month").opts(color="brown")
furance = hv.Curve(groupByMonth('Furnace'),label="Time-Series of Furnace by Month").opts(color="skyblue")
kitchen = hv.Curve(groupByMonth('Kitchen'),label="Time-Series of Kitchen by Month").opts(color="lightgreen")

(dish_w + home_o + re_fridge + wine_c + garage_d + barn + well + micro_w + living_r + furance + kitchen).opts(opts.Curve(xlabel="Month", ylabel="Energy Consumption", yformatter='%.2fkw', \
                                                                               width=400, height=300,tools=['hover'],show_grid=True)).opts(shared_axes=False).cols(6)
# Out:
# :Layout
#    .Curve.Time_hyphen_minus_Series_of_Dishwasher_by_Month  :Curve   [month]   (mean)
#    .Curve.Time_hyphen_minus_Series_of_Home_office_by_Month :Curve   [month]   (mean)
#    .Curve.Time_hyphen_minus_Series_of_Fridge_by_Month      :Curve   [month]   (mean)
#    .Curve.Time_hyphen_minus_Series_of_Wine_cellar_by_Month :Curve   [month]   (mean)
#    .Curve.Time_hyphen_minus_Series_of_Garage_door_by_Month :Curve   [month]   (mean)
#    .Curve.Time_hyphen_minus_Series_of_Barn_by_Month        :Curve   [month]   (mean)
#    .Curve.Time_hyphen_minus_Series_of_Well_by_Month        :Curve   [month]   (mean)
#    .Curve.Time_hyphen_minus_Series_of_Microwave_by_Month   :Curve   [month]   (mean)
#    .Curve.Time_hyphen_minus_Series_of_Living_room_by_Month :Curve   [month]   (mean)
#    .Curve.Time_hyphen_minus_Series_of_Furnace_by_Month     :Curve   [month]   (mean)
#    .Curve.Time_hyphen_minus_Series_of_Kitchen_by_Month     :Curve   [month]   (mean)

# %%
dish_w = hv.Curve(groupByWeekday('Dishwasher'),label="Dishwasher Time-Series by Weekday").opts(color="red")
home = hv.Curve(groupByWeekday('Home office'),label="Home office Time-Series by Weekday").opts(color="blue")
re_fridge = hv.Curve(groupByWeekday('Fridge'),label="FridgeTime-Series by Weekday").opts(color="orange")
wine_c = hv.Curve(groupByWeekday('Wine cellar'),label="Wine cellar Time-Series by Weekday").opts(color="green")
garage_d = hv.Curve(groupByWeekday('Garage door'),label="Garage door Time-Series by Weekday").opts(color="purple")
barn = hv.Curve(groupByWeekday('Barn'),label="Barn Time-Series by Weekday").opts(color="grey")
wine = hv.Curve(groupByWeekday('Well'),label="Well Time-Series by Weekday").opts(color="pink")
micro_w = hv.Curve(groupByWeekday('Microwave'),label="Microwave Time-Series by Weekday").opts(color="yellow")
living_r = hv.Curve(groupByWeekday('Living room'),label="Living room Time-Series by Weekday").opts(color="brown")
furance = hv.Curve(groupByWeekday('Furnace'),label="Furnace Time-Series by Weekday").opts(color="skyblue")
kitchen = hv.Curve(groupByWeekday('Kitchen'),label="Kitchen Time-Series by Weekday").opts(color="lightgreen")

(dish_w + home + re_fridge + wine_c + garage_d + barn + well + micro_w + living_r + furance + kitchen).opts(opts.Curve(xlabel="Weekday", ylabel="Energy Consumption", yformatter='%.2fkw', \
                                                                               width=400, height=300,tools=['hover'],show_grid=True, xrotation=20)).opts(shared_axes=False).cols(6)
# Out:
# :Layout
#    .Curve.Dishwasher_Time_hyphen_minus_Series_by_Weekday      :Curve   [weekday]   (Dishwasher_mean)
#    .Curve.Home_office_Time_hyphen_minus_Series_by_Weekday     :Curve   [weekday]   (Home office_mean)
#    .Curve.FridgeTime_hyphen_minus_Series_by_Weekday           :Curve   [weekday]   (Fridge_mean)
#    .Curve.Wine_cellar_Time_hyphen_minus_Series_by_Weekday     :Curve   [weekday]   (Wine cellar_mean)
#    .Curve.Garage_door_Time_hyphen_minus_Series_by_Weekday     :Curve   [weekday]   (Garage door_mean)
#    .Curve.Barn_Time_hyphen_minus_Series_by_Weekday            :Curve   [weekday]   (Barn_mean)
#    .Curve.Time_hyphen_minus_Series_analysis_of_Well_by_Timing :Curve   [timing]   (Well_mean)
#    .Curve.Microwave_Time_hyphen_minus_Series_by_Weekday       :Curve   [weekday]   (Microwave_mean)
#    .Curve.Living_room_Time_hyphen_minus_Series_by_Weekday     :Curve   [weekday]   (Living room_mean)
# ...

# %%
dish_w = hv.Curve(groupByTiming('Dishwasher'),label="Time-Series analysis of Dishwasher by Timing").opts(color="red")
home_o = hv.Curve(groupByTiming('Home office'),label="Time-Series analysis of Home office by Timing").opts(color="blue")
re_fridge = hv.Curve(groupByTiming('Fridge'),label="Time-Series analysis of Fridge by Timing").opts(color="orange")
wine_c = hv.Curve(groupByTiming('Wine cellar'),label="Time-Series analysis of Wine cellar by Timing").opts(color="green")
garage_d = hv.Curve(groupByTiming('Garage door'),label="Time-Series analysis of Garage door by Timing").opts(color="purple")
barn = hv.Curve(groupByTiming('Barn'),label="Time-Series analysis of Barn by Timing").opts(color="grey")
well = hv.Curve(groupByTiming('Well'),label="Time-Series analysis of Well by Timing").opts(color="pink")
micro_w = hv.Curve(groupByTiming('Microwave'),label="Time-Series analysis of Microwave by Timing").opts(color="yellow")
living_r = hv.Curve(groupByTiming('Living room'),label="Time-Series analysis of Living room by Timing").opts(color="brown")
furance = hv.Curve(groupByTiming('Furnace'),label="Time-Series analysis of Furnaceby Timing").opts(color="skyblue")
kitchen = hv.Curve(groupByTiming('Kitchen'),label="Time-Series analysis of Kitchen by Timing").opts(color="lightgreen")

(dish_w + home_o + re_fridge + wine_c + garage_d + barn + well + micro_w + living_r + furance + kitchen).opts(opts.Curve(xlabel="Timing", ylabel="Energy Consumption", yformatter='%.2fkw', \
                                                                               width=400, height=300,tools=['hover'],show_grid=True)).opts(shared_axes=False).cols(6)
# Out:
# :Layout
#    .Curve.Time_hyphen_minus_Series_analysis_of_Dishwasher_by_Timing  :Curve   [timing]   (Dishwasher_mean)
#    .Curve.Time_hyphen_minus_Series_analysis_of_Home_office_by_Timing :Curve   [timing]   (Home office_mean)
#    .Curve.Time_hyphen_minus_Series_analysis_of_Fridge_by_Timing      :Curve   [timing]   (Fridge_mean)
#    .Curve.Time_hyphen_minus_Series_analysis_of_Wine_cellar_by_Timing :Curve   [timing]   (Wine cellar_mean)
#    .Curve.Time_hyphen_minus_Series_analysis_of_Garage_door_by_Timing :Curve   [timing]   (Garage door_mean)
#    .Curve.Time_hyphen_minus_Series_analysis_of_Barn_by_Timing        :Curve   [timing]   (Barn_mean)
#    .Curve.Time_hyphen_minus_Series_analysis_of_Well_by_Timing        :Curve   [timing]   (Well_mean)
#    .Curve.Time_hyphen_minus_Series_analysis_of_Microwave_by_Timing   :Curve   [timing]   (Microwave_mean)
#    .Curve.Time_hyphen_minus_Series_analysis_of_Living_room_by_Timing :Curve   [timing]   (Living room_mean)
# ...

# %%
tempera = hv.Curve(df['temperature'].resample('D').mean(),label="temperature").opts(color="red")
ap_Temp = hv.Curve(df['apparentTemperature'].resample('D').mean(),label="apparentTemperature").opts(color="orange")
temp_s = (tempera * ap_Temp).opts(opts.Curve(title='Temperature Time-Series by Day')).opts(legend_position='top',legend_cols=2)
humdi = hv.Curve(df['humidity'].resample('D').mean()).opts(color="yellow", title='Humidity Time-Series by Day')
visib = hv.Curve(df['visibility'].resample('D').mean()).opts(color="blue", title='Visibility Time-Series by Day')
pressure = hv.Curve(df['pressure'].resample('D').mean()).opts(color="green", title='Pressure Time-Series by Day')
wind_s = hv.Curve(df['windSpeed'].resample('D').mean()).opts(color="purple", title='WindSpeed Time-Series by Day')
cloud_s = hv.Curve(df['cloudCover'].resample('D').mean()).opts(color="grey", title='CloudCover Time-Series by Day')
precip_int = hv.Curve(df['precipIntensity'].resample('D').mean()).opts(color="skyblue", title='PrecipIntensity Time-Series by Day')
dew_po = hv.Curve(df['dewPoint'].resample('D').mean()).opts(color="lightgreen", title='DewPoint Time-Series by Day')

(temp_s + humdi + visib + pressure + wind_s + cloud_co + precip_int + dew_po).opts(opts.Curve(xlabel="Day", ylabel="Values", width=400, height=300,tools=['hover'],show_grid=True)).cols(4)
# Out:
# :Layout
#    .Overlay.I      :Overlay
#       .Curve.Temperature         :Curve   [time]   (temperature)
#       .Curve.ApparentTemperature :Curve   [time]   (apparentTemperature)
#    .Curve.I        :Curve   [time]   (humidity)
#    .Curve.II       :Curve   [time]   (visibility)
#    .Curve.III      :Curve   [time]   (pressure)
#    .Curve.IV       :Curve   [time]   (windSpeed)
#    .Distribution.I :Distribution   [cloudCover]   (Density)
#    .Curve.V        :Curve   [time]   (precipIntensity)
#    .Curve.VI       :Curve   [time]   (dewPoint)

# %%
fig,ax = plt.subplots(figsize=(10, 8))
corr = df[['Dishwasher','Home office','Fridge','Wine cellar','Garage door','Barn','Well','Microwave','Living room','Furnace','Kitchen']].corr()
sns.heatmap(corr, annot=True, vmin=-1.0, vmax=1.0, center=0)
ax.set_title('Correlation of Appliances',size=20)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(20, 12))
corr = df[['use_HO','gen_Sol','Dishwasher','Home office','Fridge','Wine cellar','Garage door','Barn','Well','Microwave','Living room','Furnace','Kitchen',\
           'temperature','apparentTemperature','humidity','visibility','pressure','windSpeed','cloudCover','precipIntensity','dewPoint']].corr()
sns.heatmap(corr, annot=True, vmin=-1.0, vmax=1.0, center=0)
ax.set_title('Correlation of Appliances & Weather Information',size=20)
plt.show()

# %% [markdown]
# # **Model**

# %%
# Change Detection Model for predicting change in Energy Consumption 

def chng_detection(col_1, _r=0.01, _order=1, _smooth=10):
    cf = changefinder.ChangeFinder(r=_r, order=_order, smooth=_smooth)
    ch_df = pd.DataFrame()
    col = 'House Overall'
    ch_df[col] = df[col_1].resample('D').mean()
    # calculate the change score
    ch_df['change_score'] = [cf.update(i) for i in ch_df[col]]
    ch_score_q1 = stats.scoreatpercentile(ch_df['change_score'], 25)
    ch_score_q3 = stats.scoreatpercentile(ch_df['change_score'], 75)
    thr_upper = ch_score_q3 + (ch_score_q3 - ch_score_q1) * 3

    anom_score = hv.Curve(ch_df['change_score'])
    anom_score_th = hv.HLine(thr_upper).opts(color='red', line_dash="dotdash")

    anom_points = [[ch_df.index[i],ch_df[col][i]] for i, score in enumerate(ch_df["change_score"]) if score > thr_upper]
    org = hv.Curve(ch_df[col],label='House Overall').opts(yformatter='%.1fkw')
    detected = hv.Points(anom_points, label=f"House Overall detected").opts(color='red', legend_position='bottom', size=5)

    return ((anom_score * anom_score_th).opts(title=f"House Overall Change Score & Threshold") + \
            (org * detected).opts(title=f"House Overall Detected Points")).opts(opts.Curve(width=800, height=300, show_grid=True, tools=['hover'])).cols(1)

# %%
chng_detection('use_HO', _r=0.001, _order=1, _smooth=3)
# Out:
# :Layout
#    .Overlay.I  :Overlay
#       .Curve.I :Curve   [time]   (change_score)
#       .HLine.I :HLine   [x,y]
#    .Overlay.II :Overlay
#       .Curve.House_Overall           :Curve   [time]   (House Overall)
#       .Points.House_Overall_detected :Points   [x,y]

# %%
# Data resampling by day
data_daily = df['use_HO'].resample('d').mean()
#Define la moving average
baseline = data_daily.rolling(window=10).mean()

daily_data_1 = hv.Curve(data_daily)
rolling_mean_1 = hv.Curve(baseline).opts(color='red', line_dash="dotdash")


(daily_data_1 * rolling_mean_1).opts(title=f"House Overall Change Score & Threshold").opts(opts.Curve(width=800, height=300, show_grid=True, tools=['hover']))
# Out:
# :Overlay
#    .Curve.I  :Curve   [time]   (use_HO)
#    .Curve.II :Curve   [time]   (use_HO)

# %%
#Rescale
data_daily_lstm = df[['use_HO', 'Furnace', 'Living room', 'Barn', 'temperature', 'humidity',
                   'apparentTemperature', 'pressure', 'cloudCover','windBearing', 'precipIntensity',
                   'dewPoint', 'precipProbability']]
data_daily = data_daily_lstm.resample('D').mean()
#Normalize the features
scaler = MinMaxScaler(feature_range=(0, 1))
data_daily[data_daily.columns[1:]] = scaler.fit_transform(data_daily[data_daily.columns[1:]])
scaler_target = MinMaxScaler(feature_range=(0, 1))
data_daily[['use_HO']] = scaler_target.fit_transform(data_daily[['use_HO']])

size = int(len(data_daily)*0.7)
data_daily_train = data_daily[:size]
data_daily_test = data_daily[size:]
X_train, X_test = [], []
Y_train, Y_test = [], []
n_past=1
n_future=1
for i in range(n_past, len(data_daily_train)-n_future+1):
    X_train.append(data_daily_train.iloc[i-n_past:i, 0:data_daily.shape[1]])
    Y_train.append(data_daily_train.iloc[i+n_future-1:i+n_future, 0])
for i in range(n_past, len(data_daily_test)-n_future+1):
    X_test.append(data_daily_test.iloc[i-n_past:i, 0:data_daily_test.shape[1]])
    Y_test.append(data_daily_test.iloc[i+n_future-1:i+n_future, 0])
    
X_train, Y_train = np.array(X_train), np.array(Y_train)
X_test, Y_test = np.array(X_test), np.array(Y_test)

print('X_train shape', X_train.shape)
print('X_test shape', X_test.shape)
print('Y_train shape', Y_train.shape)
print('Y_test shape', Y_test.shape)
# Out:
# X_train shape (244, 1, 13)
# X_test shape (105, 1, 13)
# Y_train shape (244, 1)
# Y_test shape (105, 1)

# %%
model = Sequential()
model.add(LSTM(25, activation='relu', return_sequences = False, input_shape=(X_train.shape[1], X_train.shape[2])))
#model.add(LSTM(50, activation='relu', return_sequences = True))
#model.add(LSTM(15, activation='relu', return_sequences = False))
#model.add(Dropout(0.2))
model.add(Dense(Y_train.shape[1]))
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 25)                3900
#
#  dense (Dense)               (None, 1)                 26
#
# ...
# Total params: 3926 (15.34 KB)
# Trainable params: 3926 (15.34 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_fit = model.fit(X_train, Y_train, epochs=60, verbose=0)

Train_pred = model.predict(X_train, verbose=0)
Y_pred = model.predict(X_test, verbose=0)

# %%
plt.plot(model_fit.history['loss'], label='Train loss')
plt.legend()
print('Train MSE minimum:', min(model_fit.history['loss']))
# Out:
# Train MSE minimum: 0.015937283635139465

# %%
data_daily[['use_HO']] = scaler_target.inverse_transform(data_daily[['use_HO']])
Y_pred = scaler_target.inverse_transform(Y_pred)
Train_pred = scaler_target.inverse_transform(Train_pred)

# %%
plt.figure(figsize=(15,4))
plt.plot(data_daily[['use_HO']][size:-1].values)
plt.plot(Y_pred)
np.sqrt(mean_squared_error(Y_pred[:,0].tolist(), data_daily[['use_HO']][size:-1].values))
# Out:
# 0.16852248847880547

# %%
Y_pred_series = pd.Series(Y_pred.flatten().tolist(), index=data_daily['use_HO'][size:-n_past].index)
Train_pred_series = pd.Series(Train_pred.flatten().tolist(), index=data_daily['use_HO'][n_past:size].index)
plt.figure(figsize=(15,4))
plt.plot(data_daily['use_HO'][:-n_past], c='blue', label='data')
plt.plot(Y_pred_series, c='red', label='model test')
plt.plot(Train_pred_series, c='green', label='model train')
plt.legend()
plt.grid(), plt.margins(x=0);
Y_test = data_daily['use_HO'][size:-n_past]

# calcolo errore
print('MSE: %.5f' % (mean_squared_error(Y_pred, Y_test)))
print('RMSE: %.5f' % np.sqrt(mean_squared_error(Y_pred, Y_test)))
MAE = mean_absolute_error(Y_test, Y_pred)
MAPE = np.mean(np.abs(Y_pred[:,0] - Y_test.values)/np.abs(Y_test.values))
#MASE = np.mean(np.abs(Y_test - Y_pred))/(np.abs(np.diff(X_train)).sum()/(len(X_train)-1))
print('MAE: %.3f' % MAE)
print('MAPE: %.3f' %MAPE)
#print('MASE: %.3f' %MASE)
print('R^2 score: %.3f' % r2_score(Y_test, Y_pred))
# Out:
# MSE: 0.02840
# RMSE: 0.16852
# MAE: 0.134
# MAPE: 0.208
# R^2 score: 0.620
